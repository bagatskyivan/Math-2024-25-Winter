# %% [markdown]
# FUNCTIONS
#
# ---
#
# 1. Draw in a single GeoGebra notebook the following functions:
#
#    $$
#    f(x) = x^2
#    $$
#
#    $$
#    g(x) = \sqrt{x}
#    $$
#
#    $$
#    h(x) = \frac{1}{x}
#    $$
#
#    $$
#    j(x) = \sin(x)
#    $$
#
#    Find the value of all the above functions at $x = 2$.
#
# 2. Let $f(x) = 3x - 1$ and $g(x) = \sqrt{x}$. Find:
#
#    - $f(g(x))$
#    - $g(f(x))$
#    - $f(f(x))$
#    - $g(g(x))$
#
#    Visualize the functions in a single GeoGebra notebook.
#
# 3. Let $f(x) = e^x$ and $g(x) = \ln(x)$. Check $f(g(x))$ and $g(f(x))$. What do you notice?
#
# 4. We have the function $f = \{(1, 7), (2, 9), (3, 11)\}$. Give the inverse function $f^{-1}$.
#
# 5. We have the function $f = \{(1, 7), (2, 7), (3, 11)\}$. Give the inverse function $f^{-1}$.
#
# 6. We have the function $f(x) = x - 1$. Give the inverse function $f^{-1}$. Show both functions on the same GeoGebra notebook.

# %% [markdown]
# # **1**.
#
#
# https://www.geogebra.org/calculator/wyubkgrb
#
# # **2**.
# Here’s the solution correctly formatted for Google Colab using \$...\$ for inline math and \$\$...\$\$ for display math:
#
# ---
#
# ### 1. **Find \( f(g(x)) \):**
#
# We are given \( f(x) = 3x - 1 \) and \( g(x) =$$ \sqrt{x} $$
#
# $$
# f(g(x)) = f(\sqrt{x}) = 3\sqrt{x} - 1
# $$
#
# So:
# $$
# f(g(x)) = 3\sqrt{x} - 1
# $$
#
# ---
#
# ### 2. **Find \( g(f(x)) \):**
#
# We are given \( f(x) = 3x - 1 \) and \( g(x) = $$\sqrt{x} .$$
#
# $$
# g(f(x)) = g(3x - 1) = \sqrt{3x - 1}
# $$
#
# Thus:
# $$
# g(f(x)) = \sqrt{3x - 1}
# $$
#
# ---
#
# ### 3. **Find \( f(f(x)) \):**
#
# We are given \( f(x) = 3x - 1 \).
#
# $$
# f(f(x)) = f(3x - 1) = 3(3x - 1) - 1
# $$
#
# Simplify:
# $$
# f(f(x)) = 9x - 3 - 1 = 9x - 4
# $$
#
# So:
# $$
# f(f(x)) = 9x - 4
# $$
#
# ---
#
# ### 4. **Find \( g(g(x)) \):**
#
# We are given \ g(x) = $$\sqrt{x} $$.
#
# $$
# g(g(x)) = g(\sqrt{x}) = \sqrt{\sqrt{x}} = x^{1/4}
# $$
#
# Thus:
# $$
# g(g(x)) = x^{1/4}
# $$
#
# ---
#
# ### Final Results:
#
# $$
# \begin{aligned}
# f(g(x)) &= 3\sqrt{x} - 1, \\
# g(f(x)) &= \sqrt{3x - 1}, \\
# f(f(x)) &= 9x - 4, \\
# g(g(x)) &= x^{1/4}.
# \end{aligned}
# $$
#
#
# https://www.geogebra.org/calculator/gmhmpudh
#
#
# # **3.**
#
#
#
# ### 1. **Find \( f(g(x)) \):**
#
# We are given \( f(x) = e^x \) and \( g(x) = \ln(x) \).
#
# $$
# f(g(x)) = f(\ln(x)) = e^{\ln(x)}
# $$
#
# We know that \( e^{\ln(x)} = x \), so:
#
# $$
# f(g(x)) = x
# $$
#
# ---
#
# ### 2. **Find \( g(f(x)) \):**
#
# We are given \( f(x) = e^x \) and \( g(x) = \ln(x) \).
#
# $$
# g(f(x)) = g(e^x) = \ln(e^x)
# $$
#
# We know that \( \ln(e^x) = x \), so:
#
# $$
# g(f(x)) = x
# $$
#
# ---
#
# ### Observation:
#
# - \( f(g(x)) = x \)
# - \( g(f(x)) = x \)
#
# Thus, for these functions, the compositions \( f(g(x)) \) and \( g(f(x)) \) yield the identity function \( x \), meaning they "undo" each other. This is a special property of the exponential and logarithmic functions: they are inverses of each other.
#
#
# # **4.**
#
# To find the inverse function \( f^{-1} \), we simply swap the coordinates in each pair from the original function \( f \). The function \( f = \{(1, 7), (2, 9), (3, 11)\} \) consists of the following pairs:
#
# - \( (1, 7) \)
# - \( (2, 9) \)
# - \( (3, 11) \)
#
# Now, to find \( f^{-1} \), we swap each pair:
#
# - \( (7, 1) \)
# - \( (9, 2) \)
# - \( (11, 3) \)
#
# Thus, the inverse function is:
#
# $$
# f^{-1} = \{(7, 1), (9, 2), (11, 3)\}
# $$
#
# This means that in \( f^{-1} \), the input is the output of \( f \), and the output is the input of \( f \).
#
#
# # **5.**
#
# For a function to have an inverse, it must be **one-to-one** (meaning each input corresponds to exactly one output).
#
#  The function \( f = \{(1, 7), (2, 7), (3, 11)\} \) is
#  not one-to-one
#  because both \( 1 \) and \( 2 \) map to the same value, \( 7 \).
#
# Since a function is not one-to-one if two distinct inputs map to the same output, this function does **not** have an inverse.
#
# In other words, the inverse function $$ f^{-1} $$ does not exist in this case.
#
#
#
#
# # **6.**
# ---
#
# ### Finding the Inverse of \( f(x) = x - 1 \):
#
# To find the inverse of \( f(x) = x - 1 \), follow these steps:
#
# 1. Replace \( f(x) \) with \( y \):
#    $$ y = x - 1 $$
#
# 2. Swap \( x \) and \( y \) to get the inverse:
#    $$ x = y - 1 $$
#
# 3. Solve for \( y \):
#    $$ y = x + 1 $$
#
# So, the inverse function is:
# $$ f^{-1}(x) = x + 1 $$
#
# ---
#
# https://www.geogebra.org/calculator/xqdxtveh
